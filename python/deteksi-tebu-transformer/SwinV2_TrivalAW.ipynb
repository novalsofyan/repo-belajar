# %%
import torch
from torch import nn

# %%
from scripts import muat_datasets
from pathlib import Path

data_path = Path('datasets')
train_dir, test_dir = muat_datasets.muat_data(data_path)
# Out:
# Path dataset sudah benar!

# %%
train_dir, test_dir
# Out:
# (WindowsPath('datasets/train'), WindowsPath('datasets/test'))

# %%
from scripts import visualization

visualization.cek_gambar(data_path)
# Out:
# Direktori gambar: datasets\train\red_rot\redrot (143).jpeg
# Class gambar: red_rot
# Tinggi gambar: 918
# Lebar gambar: 750

# %%
import torchvision

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
weights = torchvision.models.Swin_V2_B_Weights.DEFAULT
weights
# Out:
# Swin_V2_B_Weights.IMAGENET1K_V1

# %%
auto_transforms = weights.transforms()
auto_transforms
# Out:
# ImageClassification(
#     crop_size=[256]
#     resize_size=[272]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BICUBIC
# )

# %%
from torchvision.transforms import v2

# %%
train_transform = v2.Compose([
    v2.Resize(size = [256, 256]),
    # v2.Grayscale(num_output_channels = 1),
    # v2.AugMix(),
    v2.TrivialAugmentWide(num_magnitude_bins = 31),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
])

test_transform = v2.Compose([
    v2.Resize(size = [256, 256]),
    # v2.Grayscale(num_output_channels = 1),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
])

# %%
train_data_loader, test_data_loader, class_names = muat_datasets.dataLoader(train_dir = train_dir,
                                                                            test_dir = test_dir,
                                                                            batch_size = 32, num_workers = 4,
                                                                            train_transform = train_transform,
                                                                            test_transform = test_transform)
train_data_loader, test_data_loader, class_names
# Out:
# Membuat DataLoader dengan ukuran batch 32 dan 4 workers.
# (<torch.utils.data.dataloader.DataLoader at 0x1883133fce0>,
#  <torch.utils.data.dataloader.DataLoader at 0x1883122bc50>,
#  ['healthy', 'mosaic', 'red_rot', 'rust', 'yellow'])

# %%
image_batch, label_batch = next(iter(train_data_loader))

# %%
visualization.cek_gambar_dl(image_batch = image_batch, label_batch = label_batch, class_names = class_names)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Shape gambar: torch.Size([3, 256, 256])
# Class gambar (bentuk angka): 4

# %% [markdown]
# # SWIN Transformer Step-by-Step

# %%
model = torchvision.models.swin_v2_b(weights = weights).to(device)

# %%
from torchinfo import summary

# %%
summary(model = model, 
        input_size=(32, 3, 256, 256), # make sure this is "input_size", not "input_shape"
        # col_names=["input_size"], # uncomment for smaller output
        col_names=['input_size', 'output_size', 'num_params', 'trainable'],
        col_width=20,
        row_settings=["var_names"])
# Out:
# =======================================================================================================================================
# Layer (type (var_name))                                 Input Shape          Output Shape         Param #              Trainable
# =======================================================================================================================================
# SwinTransformer (SwinTransformer)                       [32, 3, 256, 256]    [32, 1000]           --                   True
# ├─Sequential (features)                                 [32, 3, 256, 256]    [32, 8, 8, 1024]     --                   True
# │    └─Sequential (0)                                   [32, 3, 256, 256]    [32, 64, 64, 128]    --                   True
# │    │    └─Conv2d (0)                                  [32, 3, 256, 256]    [32, 128, 64, 64]    6,272                True
# │    │    └─Permute (1)                                 [32, 128, 64, 64]    [32, 64, 64, 128]    --                   --
# │    │    └─LayerNorm (2)                               [32, 64, 64, 128]    [32, 64, 64, 128]    256                  True
# │    └─Sequential (1)                                   [32, 64, 64, 128]    [32, 64, 64, 128]    --                   True
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 64, 64, 128]    [32, 64, 64, 128]    201,860              True
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 64, 64, 128]    [32, 64, 64, 128]    201,860              True
# │    └─PatchMergingV2 (2)                               [32, 64, 64, 128]    [32, 32, 32, 256]    --                   True
# │    │    └─Linear (reduction)                          [32, 32, 32, 512]    [32, 32, 32, 256]    131,072              True
# │    │    └─LayerNorm (norm)                            [32, 32, 32, 256]    [32, 32, 32, 256]    512                  True
# │    └─Sequential (3)                                   [32, 32, 32, 256]    [32, 32, 32, 256]    --                   True
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 32, 32, 256]    [32, 32, 32, 256]    795,400              True
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 32, 32, 256]    [32, 32, 32, 256]    795,400              True
# │    └─PatchMergingV2 (4)                               [32, 32, 32, 256]    [32, 16, 16, 512]    --                   True
# │    │    └─Linear (reduction)                          [32, 16, 16, 1024]   [32, 16, 16, 512]    524,288              True
# │    │    └─LayerNorm (norm)                            [32, 16, 16, 512]    [32, 16, 16, 512]    1,024                True
# │    └─Sequential (5)                                   [32, 16, 16, 512]    [32, 16, 16, 512]    --                   True
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (2)                  [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (3)                  [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (4)                  [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (5)                  [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (6)                  [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (7)                  [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (8)                  [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (9)                  [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (10)                 [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (11)                 [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (12)                 [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (13)                 [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (14)                 [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (15)                 [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (16)                 [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (17)                 [32, 16, 16, 512]    [32, 16, 16, 512]    3,162,128            True
# │    └─PatchMergingV2 (6)                               [32, 16, 16, 512]    [32, 8, 8, 1024]     --                   True
# │    │    └─Linear (reduction)                          [32, 8, 8, 2048]     [32, 8, 8, 1024]     2,097,152            True
# │    │    └─LayerNorm (norm)                            [32, 8, 8, 1024]     [32, 8, 8, 1024]     2,048                True
# │    └─Sequential (7)                                   [32, 8, 8, 1024]     [32, 8, 8, 1024]     --                   True
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 8, 8, 1024]     [32, 8, 8, 1024]     12,614,176           True
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 8, 8, 1024]     [32, 8, 8, 1024]     12,614,176           True
# ├─LayerNorm (norm)                                      [32, 8, 8, 1024]     [32, 8, 8, 1024]     2,048                True
# ├─Permute (permute)                                     [32, 8, 8, 1024]     [32, 1024, 8, 8]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                           [32, 1024, 8, 8]     [32, 1024, 1, 1]     --                   --
# ├─Flatten (flatten)                                     [32, 1024, 1, 1]     [32, 1024]           --                   --
# ├─Linear (head)                                         [32, 1024]           [32, 1000]           1,025,000            True
# =======================================================================================================================================
# Total params: 87,930,848
# Trainable params: 87,930,848
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.73
# =======================================================================================================================================
# Input size (MB): 25.17
# Forward/backward pass size (MB): 7824.46
# Params size (MB): 239.86
# Estimated Total Size (MB): 8089.48
# =======================================================================================================================================

# %%
for param in model.features.parameters():
    param.requires_grad = False

# %%
from scripts import helper

# %%
helper.set_seeds()

output_shape = len(class_names)

model.head = torch.nn.Sequential(
    torch.nn.Linear(in_features=1024, 
                    out_features = output_shape, # same number of output units as our number of classes
                    bias=True)).to(device)

# %%
summary(model = model, 
        input_size=(32, 3, 256, 256), # make sure this is "input_size", not "input_shape"
        # col_names=["input_size"], # uncomment for smaller output
        col_names=['input_size', 'output_size', 'num_params', 'trainable'],
        col_width=20,
        row_settings=["var_names"])
# Out:
# =======================================================================================================================================
# Layer (type (var_name))                                 Input Shape          Output Shape         Param #              Trainable
# =======================================================================================================================================
# SwinTransformer (SwinTransformer)                       [32, 3, 256, 256]    [32, 5]              --                   Partial
# ├─Sequential (features)                                 [32, 3, 256, 256]    [32, 8, 8, 1024]     --                   False
# │    └─Sequential (0)                                   [32, 3, 256, 256]    [32, 64, 64, 128]    --                   False
# │    │    └─Conv2d (0)                                  [32, 3, 256, 256]    [32, 128, 64, 64]    (6,272)              False
# │    │    └─Permute (1)                                 [32, 128, 64, 64]    [32, 64, 64, 128]    --                   --
# │    │    └─LayerNorm (2)                               [32, 64, 64, 128]    [32, 64, 64, 128]    (256)                False
# │    └─Sequential (1)                                   [32, 64, 64, 128]    [32, 64, 64, 128]    --                   False
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 64, 64, 128]    [32, 64, 64, 128]    (201,860)            False
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 64, 64, 128]    [32, 64, 64, 128]    (201,860)            False
# │    └─PatchMergingV2 (2)                               [32, 64, 64, 128]    [32, 32, 32, 256]    --                   False
# │    │    └─Linear (reduction)                          [32, 32, 32, 512]    [32, 32, 32, 256]    (131,072)            False
# │    │    └─LayerNorm (norm)                            [32, 32, 32, 256]    [32, 32, 32, 256]    (512)                False
# │    └─Sequential (3)                                   [32, 32, 32, 256]    [32, 32, 32, 256]    --                   False
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 32, 32, 256]    [32, 32, 32, 256]    (795,400)            False
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 32, 32, 256]    [32, 32, 32, 256]    (795,400)            False
# │    └─PatchMergingV2 (4)                               [32, 32, 32, 256]    [32, 16, 16, 512]    --                   False
# │    │    └─Linear (reduction)                          [32, 16, 16, 1024]   [32, 16, 16, 512]    (524,288)            False
# │    │    └─LayerNorm (norm)                            [32, 16, 16, 512]    [32, 16, 16, 512]    (1,024)              False
# │    └─Sequential (5)                                   [32, 16, 16, 512]    [32, 16, 16, 512]    --                   False
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (2)                  [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (3)                  [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (4)                  [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (5)                  [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (6)                  [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (7)                  [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (8)                  [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (9)                  [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (10)                 [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (11)                 [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (12)                 [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (13)                 [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (14)                 [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (15)                 [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (16)                 [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (17)                 [32, 16, 16, 512]    [32, 16, 16, 512]    (3,162,128)          False
# │    └─PatchMergingV2 (6)                               [32, 16, 16, 512]    [32, 8, 8, 1024]     --                   False
# │    │    └─Linear (reduction)                          [32, 8, 8, 2048]     [32, 8, 8, 1024]     (2,097,152)          False
# │    │    └─LayerNorm (norm)                            [32, 8, 8, 1024]     [32, 8, 8, 1024]     (2,048)              False
# │    └─Sequential (7)                                   [32, 8, 8, 1024]     [32, 8, 8, 1024]     --                   False
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 8, 8, 1024]     [32, 8, 8, 1024]     (12,614,176)         False
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 8, 8, 1024]     [32, 8, 8, 1024]     (12,614,176)         False
# ├─LayerNorm (norm)                                      [32, 8, 8, 1024]     [32, 8, 8, 1024]     2,048                True
# ├─Permute (permute)                                     [32, 8, 8, 1024]     [32, 1024, 8, 8]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                           [32, 1024, 8, 8]     [32, 1024, 1, 1]     --                   --
# ├─Flatten (flatten)                                     [32, 1024, 1, 1]     [32, 1024]           --                   --
# ├─Sequential (head)                                     [32, 1024]           [32, 5]              --                   True
# │    └─Linear (0)                                       [32, 1024]           [32, 5]              5,125                True
# =======================================================================================================================================
# Total params: 86,910,973
# Trainable params: 7,173
# Non-trainable params: 86,903,800
# Total mult-adds (Units.GIGABYTES): 2.70
# =======================================================================================================================================
# Input size (MB): 25.17
# Forward/backward pass size (MB): 7824.20
# Params size (MB): 235.78
# Estimated Total Size (MB): 8085.14
# =======================================================================================================================================

# %%
# Define loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)

# %%
from scripts import engine
# Set the random seeds
helper.set_seeds()

# Start the timer
from timeit import default_timer as timer 
start_time = timer()

# Setup training and save the results
results = engine.train(model=model,
                       train_dataloader = train_data_loader,
                       test_dataloader = test_data_loader,
                       optimizer = optimizer,
                       loss_fn = loss_fn,
                       epochs = 20,
                       device = device)

# End the timer and print out how long it took
end_time = timer()
print(f'Total waktu train: {end_time-start_time:.3f} detik')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1330 | train_acc: 0.5862 | test_loss: 1.0603 | test_acc: 0.6238
# Epoch: 2 | train_loss: 0.7312 | train_acc: 0.7646 | test_loss: 0.8769 | test_acc: 0.6945
# Epoch: 3 | train_loss: 0.6189 | train_acc: 0.8062 | test_loss: 0.7949 | test_acc: 0.7234
# Epoch: 4 | train_loss: 0.5532 | train_acc: 0.8248 | test_loss: 0.8048 | test_acc: 0.7156
# Epoch: 5 | train_loss: 0.5074 | train_acc: 0.8390 | test_loss: 0.8113 | test_acc: 0.6902
# Epoch: 6 | train_loss: 0.4693 | train_acc: 0.8543 | test_loss: 0.7026 | test_acc: 0.7531
# Epoch: 7 | train_loss: 0.4443 | train_acc: 0.8618 | test_loss: 0.6568 | test_acc: 0.7719
# Epoch: 8 | train_loss: 0.4255 | train_acc: 0.8604 | test_loss: 0.7366 | test_acc: 0.7492
# Epoch: 9 | train_loss: 0.3934 | train_acc: 0.8740 | test_loss: 0.6668 | test_acc: 0.7641
# Epoch: 10 | train_loss: 0.3766 | train_acc: 0.8789 | test_loss: 0.6563 | test_acc: 0.7727
# Epoch: 11 | train_loss: 0.3833 | train_acc: 0.8706 | test_loss: 0.6424 | test_acc: 0.7609
# Epoch: 12 | train_loss: 0.3483 | train_acc: 0.8892 | test_loss: 0.5849 | test_acc: 0.8082
# Epoch: 13 | train_loss: 0.3324 | train_acc: 0.8955 | test_loss: 0.5998 | test_acc: 0.8063
# Epoch: 14 | train_loss: 0.3450 | train_acc: 0.8816 | test_loss: 0.5777 | test_acc: 0.8121
# Epoch: 15 | train_loss: 0.3192 | train_acc: 0.8987 | test_loss: 0.5868 | test_acc: 0.8160
# Epoch: 16 | train_loss: 0.3242 | train_acc: 0.8851 | test_loss: 0.6547 | test_acc: 0.7562
# Epoch: 17 | train_loss: 0.3280 | train_acc: 0.8870 | test_loss: 0.5910 | test_acc: 0.8070
# Epoch: 18 | train_loss: 0.3121 | train_acc: 0.8965 | test_loss: 0.5998 | test_acc: 0.8051
# Epoch: 19 | train_loss: 0.3136 | train_acc: 0.8943 | test_loss: 0.5890 | test_acc: 0.8168
# Epoch: 20 | train_loss: 0.2834 | train_acc: 0.9106 | test_loss: 0.5497 | test_acc: 0.8180
# Total waktu train: 1371.440 detik

# %%
PATH = Path('model')
MODEL_NAME = 'SwinV2_daun_tebu_TrivialAW_Norm.pth'

SAVE_PATH = PATH/MODEL_NAME

# %%
print(f'Saving model to: {SAVE_PATH}')
torch.save(obj = model.state_dict(), # only saving the state_dict() only saves the learned parameters
           f = SAVE_PATH)
# Out:
# Saving model to: model\SwinV2_daun_tebu_TrivialAW_Norm.pth

# %%
custom_img_path = Path('datasets/test/healthy/healthy (11).jpeg')

# %%
from scripts import prediksi
prediksi.plot_grafik_loss(results)

# %%
prediksi.pred_gambar(model = model,
                image_path = custom_img_path,
                class_names=class_names,
                transform = test_transform,
                device = device)

# %%
prediksi.confusion_matrix(
    model = model,
    test_dataloader = test_data_loader,
    device = device,
    class_names = class_names
)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
