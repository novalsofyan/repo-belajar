# %%
import torch
from torch import nn

# %%
from scripts import muat_datasets
from pathlib import Path

data_path = Path('datasets')
train_dir, test_dir = muat_datasets.muat_data(data_path)
# Out:
# Path dataset sudah benar!

# %%
train_dir, test_dir
# Out:
# (WindowsPath('datasets/train'), WindowsPath('datasets/test'))

# %%
from scripts import visualization

visualization.cek_gambar(data_path)
# Out:
# Direktori gambar: datasets\train\red_rot\redrot (143).jpeg
# Class gambar: red_rot
# Tinggi gambar: 918
# Lebar gambar: 750

# %%
import torchvision

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
weights = torchvision.models.Swin_V2_B_Weights.DEFAULT
weights
# Out:
# Swin_V2_B_Weights.IMAGENET1K_V1

# %%
auto_transforms = weights.transforms()
auto_transforms
# Out:
# ImageClassification(
#     crop_size=[256]
#     resize_size=[272]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BICUBIC
# )

# %%
from torchvision.transforms import v2

# %%
train_transform = v2.Compose([
    v2.Resize(size = [256, 256]),
    # v2.Grayscale(num_output_channels = 1),
    v2.AugMix(),
    v2.TrivialAugmentWide(num_magnitude_bins = 31),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
])

test_transform = v2.Compose([
    v2.Resize(size = [256, 256]),
    # v2.Grayscale(num_output_channels = 1),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
])

# %%
train_data_loader, test_data_loader, class_names = muat_datasets.dataLoader(train_dir = train_dir,
                                                                            test_dir = test_dir,
                                                                            batch_size = 32, num_workers = 4,
                                                                            train_transform = auto_transforms,
                                                                            test_transform = auto_transforms)
train_data_loader, test_data_loader, class_names
# Out:
# Membuat DataLoader dengan ukuran batch 32 dan 4 workers.
# (<torch.utils.data.dataloader.DataLoader at 0x1ad6f5eac30>,
#  <torch.utils.data.dataloader.DataLoader at 0x1ad6f5ea600>,
#  ['healthy', 'mosaic', 'red_rot', 'rust', 'yellow'])

# %%
image_batch, label_batch = next(iter(train_data_loader))

# %%
visualization.cek_gambar_dl(image_batch = image_batch, label_batch = label_batch, class_names = class_names)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Shape gambar: torch.Size([3, 256, 256])
# Class gambar (bentuk angka): 3

# %% [markdown]
# # SWIN Transformer Step-by-Step

# %%
model = torchvision.models.swin_v2_b(weights = weights).to(device)

# %%
from torchinfo import summary

# %%
summary(model = model, 
        input_size=(32, 3, 224, 224), # make sure this is "input_size", not "input_shape"
        # col_names=["input_size"], # uncomment for smaller output
        col_names=['input_size', 'output_size', 'num_params', 'trainable'],
        col_width=20,
        row_settings=["var_names"])
# Out:
# =======================================================================================================================================
# Layer (type (var_name))                                 Input Shape          Output Shape         Param #              Trainable
# =======================================================================================================================================
# SwinTransformer (SwinTransformer)                       [32, 3, 224, 224]    [32, 1000]           --                   True
# ├─Sequential (features)                                 [32, 3, 224, 224]    [32, 7, 7, 1024]     --                   True
# │    └─Sequential (0)                                   [32, 3, 224, 224]    [32, 56, 56, 128]    --                   True
# │    │    └─Conv2d (0)                                  [32, 3, 224, 224]    [32, 128, 56, 56]    6,272                True
# │    │    └─Permute (1)                                 [32, 128, 56, 56]    [32, 56, 56, 128]    --                   --
# │    │    └─LayerNorm (2)                               [32, 56, 56, 128]    [32, 56, 56, 128]    256                  True
# │    └─Sequential (1)                                   [32, 56, 56, 128]    [32, 56, 56, 128]    --                   True
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 56, 56, 128]    [32, 56, 56, 128]    201,860              True
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 56, 56, 128]    [32, 56, 56, 128]    201,860              True
# │    └─PatchMergingV2 (2)                               [32, 56, 56, 128]    [32, 28, 28, 256]    --                   True
# │    │    └─Linear (reduction)                          [32, 28, 28, 512]    [32, 28, 28, 256]    131,072              True
# │    │    └─LayerNorm (norm)                            [32, 28, 28, 256]    [32, 28, 28, 256]    512                  True
# │    └─Sequential (3)                                   [32, 28, 28, 256]    [32, 28, 28, 256]    --                   True
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 28, 28, 256]    [32, 28, 28, 256]    795,400              True
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 28, 28, 256]    [32, 28, 28, 256]    795,400              True
# │    └─PatchMergingV2 (4)                               [32, 28, 28, 256]    [32, 14, 14, 512]    --                   True
# │    │    └─Linear (reduction)                          [32, 14, 14, 1024]   [32, 14, 14, 512]    524,288              True
# │    │    └─LayerNorm (norm)                            [32, 14, 14, 512]    [32, 14, 14, 512]    1,024                True
# │    └─Sequential (5)                                   [32, 14, 14, 512]    [32, 14, 14, 512]    --                   True
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (2)                  [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (3)                  [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (4)                  [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (5)                  [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (6)                  [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (7)                  [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (8)                  [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (9)                  [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (10)                 [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (11)                 [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (12)                 [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (13)                 [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (14)                 [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (15)                 [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (16)                 [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    │    └─SwinTransformerBlockV2 (17)                 [32, 14, 14, 512]    [32, 14, 14, 512]    3,162,128            True
# │    └─PatchMergingV2 (6)                               [32, 14, 14, 512]    [32, 7, 7, 1024]     --                   True
# │    │    └─Linear (reduction)                          [32, 7, 7, 2048]     [32, 7, 7, 1024]     2,097,152            True
# │    │    └─LayerNorm (norm)                            [32, 7, 7, 1024]     [32, 7, 7, 1024]     2,048                True
# │    └─Sequential (7)                                   [32, 7, 7, 1024]     [32, 7, 7, 1024]     --                   True
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 7, 7, 1024]     [32, 7, 7, 1024]     12,614,176           True
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 7, 7, 1024]     [32, 7, 7, 1024]     12,614,176           True
# ├─LayerNorm (norm)                                      [32, 7, 7, 1024]     [32, 7, 7, 1024]     2,048                True
# ├─Permute (permute)                                     [32, 7, 7, 1024]     [32, 1024, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                           [32, 1024, 7, 7]     [32, 1024, 1, 1]     --                   --
# ├─Flatten (flatten)                                     [32, 1024, 1, 1]     [32, 1024]           --                   --
# ├─Linear (head)                                         [32, 1024]           [32, 1000]           1,025,000            True
# =======================================================================================================================================
# Total params: 87,930,848
# Trainable params: 87,930,848
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.54
# =======================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 5996.00
# Params size (MB): 239.86
# Estimated Total Size (MB): 6255.13
# =======================================================================================================================================

# %%
for param in model.features.parameters():
    param.requires_grad = False

# %%
from scripts import helper

# %%
helper.set_seeds()

output_shape = len(class_names)

model.head = torch.nn.Sequential(
    torch.nn.Linear(in_features=1024, 
                    out_features = output_shape, # same number of output units as our number of classes
                    bias=True)).to(device)

# %%
summary(model = model, 
        input_size=(32, 3, 224, 224), # make sure this is "input_size", not "input_shape"
        # col_names=["input_size"], # uncomment for smaller output
        col_names=['input_size', 'output_size', 'num_params', 'trainable'],
        col_width=20,
        row_settings=["var_names"])
# Out:
# =======================================================================================================================================
# Layer (type (var_name))                                 Input Shape          Output Shape         Param #              Trainable
# =======================================================================================================================================
# SwinTransformer (SwinTransformer)                       [32, 3, 224, 224]    [32, 5]              --                   Partial
# ├─Sequential (features)                                 [32, 3, 224, 224]    [32, 7, 7, 1024]     --                   False
# │    └─Sequential (0)                                   [32, 3, 224, 224]    [32, 56, 56, 128]    --                   False
# │    │    └─Conv2d (0)                                  [32, 3, 224, 224]    [32, 128, 56, 56]    (6,272)              False
# │    │    └─Permute (1)                                 [32, 128, 56, 56]    [32, 56, 56, 128]    --                   --
# │    │    └─LayerNorm (2)                               [32, 56, 56, 128]    [32, 56, 56, 128]    (256)                False
# │    └─Sequential (1)                                   [32, 56, 56, 128]    [32, 56, 56, 128]    --                   False
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 56, 56, 128]    [32, 56, 56, 128]    (201,860)            False
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 56, 56, 128]    [32, 56, 56, 128]    (201,860)            False
# │    └─PatchMergingV2 (2)                               [32, 56, 56, 128]    [32, 28, 28, 256]    --                   False
# │    │    └─Linear (reduction)                          [32, 28, 28, 512]    [32, 28, 28, 256]    (131,072)            False
# │    │    └─LayerNorm (norm)                            [32, 28, 28, 256]    [32, 28, 28, 256]    (512)                False
# │    └─Sequential (3)                                   [32, 28, 28, 256]    [32, 28, 28, 256]    --                   False
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 28, 28, 256]    [32, 28, 28, 256]    (795,400)            False
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 28, 28, 256]    [32, 28, 28, 256]    (795,400)            False
# │    └─PatchMergingV2 (4)                               [32, 28, 28, 256]    [32, 14, 14, 512]    --                   False
# │    │    └─Linear (reduction)                          [32, 14, 14, 1024]   [32, 14, 14, 512]    (524,288)            False
# │    │    └─LayerNorm (norm)                            [32, 14, 14, 512]    [32, 14, 14, 512]    (1,024)              False
# │    └─Sequential (5)                                   [32, 14, 14, 512]    [32, 14, 14, 512]    --                   False
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (2)                  [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (3)                  [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (4)                  [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (5)                  [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (6)                  [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (7)                  [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (8)                  [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (9)                  [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (10)                 [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (11)                 [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (12)                 [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (13)                 [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (14)                 [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (15)                 [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (16)                 [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    │    └─SwinTransformerBlockV2 (17)                 [32, 14, 14, 512]    [32, 14, 14, 512]    (3,162,128)          False
# │    └─PatchMergingV2 (6)                               [32, 14, 14, 512]    [32, 7, 7, 1024]     --                   False
# │    │    └─Linear (reduction)                          [32, 7, 7, 2048]     [32, 7, 7, 1024]     (2,097,152)          False
# │    │    └─LayerNorm (norm)                            [32, 7, 7, 1024]     [32, 7, 7, 1024]     (2,048)              False
# │    └─Sequential (7)                                   [32, 7, 7, 1024]     [32, 7, 7, 1024]     --                   False
# │    │    └─SwinTransformerBlockV2 (0)                  [32, 7, 7, 1024]     [32, 7, 7, 1024]     (12,614,176)         False
# │    │    └─SwinTransformerBlockV2 (1)                  [32, 7, 7, 1024]     [32, 7, 7, 1024]     (12,614,176)         False
# ├─LayerNorm (norm)                                      [32, 7, 7, 1024]     [32, 7, 7, 1024]     2,048                True
# ├─Permute (permute)                                     [32, 7, 7, 1024]     [32, 1024, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                           [32, 1024, 7, 7]     [32, 1024, 1, 1]     --                   --
# ├─Flatten (flatten)                                     [32, 1024, 1, 1]     [32, 1024]           --                   --
# ├─Sequential (head)                                     [32, 1024]           [32, 5]              --                   True
# │    └─Linear (0)                                       [32, 1024]           [32, 5]              5,125                True
# =======================================================================================================================================
# Total params: 86,910,973
# Trainable params: 7,173
# Non-trainable params: 86,903,800
# Total mult-adds (Units.GIGABYTES): 2.51
# =======================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 5995.75
# Params size (MB): 235.78
# Estimated Total Size (MB): 6250.79
# =======================================================================================================================================

# %%
# Define loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)

# %%
from scripts import engine
# Set the random seeds
helper.set_seeds()

# Start the timer
from timeit import default_timer as timer 
start_time = timer()

# Setup training and save the results
results = engine.train(model=model,
                       train_dataloader = train_data_loader,
                       test_dataloader = test_data_loader,
                       optimizer = optimizer,
                       loss_fn = loss_fn,
                       epochs = 20,
                       device = device)

# End the timer and print out how long it took
end_time = timer()
print(f'Total waktu train: {end_time-start_time:.3f} detik')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.0795 | train_acc: 0.6053 | test_loss: 1.0427 | test_acc: 0.6227
# Epoch: 2 | train_loss: 0.6854 | train_acc: 0.7852 | test_loss: 0.8277 | test_acc: 0.7254
# Epoch: 3 | train_loss: 0.5591 | train_acc: 0.8262 | test_loss: 0.7389 | test_acc: 0.7500
# Epoch: 4 | train_loss: 0.4991 | train_acc: 0.8385 | test_loss: 0.7671 | test_acc: 0.7168
# Epoch: 5 | train_loss: 0.4586 | train_acc: 0.8565 | test_loss: 0.7217 | test_acc: 0.7148
# Epoch: 6 | train_loss: 0.4199 | train_acc: 0.8533 | test_loss: 0.6448 | test_acc: 0.7875
# Epoch: 7 | train_loss: 0.3799 | train_acc: 0.8774 | test_loss: 0.6044 | test_acc: 0.7816
# Epoch: 8 | train_loss: 0.3595 | train_acc: 0.8911 | test_loss: 0.6594 | test_acc: 0.7539
# Epoch: 9 | train_loss: 0.3328 | train_acc: 0.8970 | test_loss: 0.5966 | test_acc: 0.7855
# Epoch: 10 | train_loss: 0.3160 | train_acc: 0.9121 | test_loss: 0.5780 | test_acc: 0.7887
# Epoch: 11 | train_loss: 0.3058 | train_acc: 0.8979 | test_loss: 0.5731 | test_acc: 0.7668
# Epoch: 12 | train_loss: 0.2862 | train_acc: 0.9170 | test_loss: 0.5331 | test_acc: 0.8063
# Epoch: 13 | train_loss: 0.2836 | train_acc: 0.9058 | test_loss: 0.5547 | test_acc: 0.8063
# Epoch: 14 | train_loss: 0.2715 | train_acc: 0.9124 | test_loss: 0.5451 | test_acc: 0.7996
# Epoch: 15 | train_loss: 0.2652 | train_acc: 0.9209 | test_loss: 0.5772 | test_acc: 0.8000
# Epoch: 16 | train_loss: 0.2721 | train_acc: 0.9155 | test_loss: 0.5988 | test_acc: 0.7660
# Epoch: 17 | train_loss: 0.2609 | train_acc: 0.9187 | test_loss: 0.5449 | test_acc: 0.8012
# Epoch: 18 | train_loss: 0.2492 | train_acc: 0.9243 | test_loss: 0.5354 | test_acc: 0.8035
# Epoch: 19 | train_loss: 0.2326 | train_acc: 0.9236 | test_loss: 0.4928 | test_acc: 0.8250
# Epoch: 20 | train_loss: 0.2249 | train_acc: 0.9290 | test_loss: 0.5247 | test_acc: 0.8023
# Total waktu train: 1369.426 detik

# %%
PATH = Path('model')
MODEL_NAME = 'SwinV2_daun_tebu_AugMix_TrivialAW_Norm.pth'

SAVE_PATH = PATH/MODEL_NAME

# %%
print(f'Saving model to: {SAVE_PATH}')
torch.save(obj = model.state_dict(), # only saving the state_dict() only saves the learned parameters
           f = SAVE_PATH)
# Out:
# Saving model to: model\SwinV2_daun_tebu_AugMix_TrivialAW_Norm.pth

# %%
custom_img_path = Path('datasets/test/healthy/healthy (3).jpeg')

# %%
from scripts import prediksi
prediksi.plot_grafik_loss(results)

# %%
prediksi.pred_gambar(model = model,
                image_path = custom_img_path,
                class_names=class_names,
                transform = test_transform,
                device = device)

# %%
prediksi.confusion_matrix(
    model = model,
    test_dataloader = test_data_loader,
    device = device,
    class_names = class_names
)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
